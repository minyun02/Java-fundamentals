# %%
import pandas as pd

# %%
excelDataFrame = pd.read_excel('testExcel.xlsx')
display(excelDataFrame.head(20))
# Out:
#     time       sin       cos       tan
# 0   0.01  0.010000  0.999950  0.010000
# 1   0.03  0.029996  0.999550  0.030009
# 2   0.05  0.049979  0.998750  0.050042
# 3   0.07  0.069943  0.997551  0.070115
# 4   0.09  0.089879  0.995953  0.090244
# 5   0.11  0.109778  0.993956  0.110446
# 6   0.13  0.129634  0.991562  0.130737
# 7   0.15  0.149438  0.988771  0.151135
# 8   0.17  0.169182  0.985585  0.171657
# 9   0.19  0.188859  0.982004  0.192320
# 10  0.21  0.208460  0.978031  0.213142
# 11  0.23  0.227978  0.973666  0.234143
# 12  0.25  0.247404  0.968912  0.255342
# 13  0.27  0.266731  0.963771  0.276758
# 14  0.29  0.285952  0.958244  0.298413
# 15  0.31  0.305059  0.952334  0.320328
# 16  0.33  0.324043  0.946042  0.342525
# 17  0.35  0.342898  0.939373  0.365028
# 18  0.37  0.361615  0.932327  0.387863
# 19  0.39  0.380188  0.924909  0.411055

# %%
import matplotlib.pyplot as plt
#import numpy as np

# %%
plt.figure(figsize=(10, 4)) # 차트의 가로 세로 비율

plt.plot(excelDataFrame.time, excelDataFrame.sin, label='sin')
plt.plot(excelDataFrame.time, excelDataFrame.cos, label='cos')

# 그리드 표시 : 기본 false
plt.grid(True)

# 라벨표시
plt.xlabel('X-label')
plt.ylabel('Y-label')

# 측범위 설정 1
#plt.xlim(-5, 12)
#plt.ylim(-1.5,1.5)

# 측범위 설정 2
#         x측, y측
#plt.axis([-2,12,-1.0,1.0])


#plt.show() # 차트를 보여줌    이미지로 차트를 저장하기 위해서는 show()를 하지말아야한다.

plt.savefig('d:/pyFile/Sincos.png')
